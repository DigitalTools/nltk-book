# %%
import nltk, re, pprint
from nltk import word_tokenize

# %% [markdown]
# ## 3.1 Accessing Text from the Web and from Disk

# %% [markdown]
# ### Electronic Books

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 1176896

# %%
raw[:75]
# Out:
# 'The Project Gutenberg EBook of Crime and Punishment, by Fyodor Dostoevsky\r\n'

# %%
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 254352

# %%
tokens[:10]
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by']

# %%
text = nltk.Text(tokens)
type(text)
# Out:
# nltk.text.Text

# %%
text[1024:1062]
# Out:
# ['CHAPTER',
#  'I',
#  'On',
#  'an',
#  'exceptionally',
#  'hot',
#  'evening',
#  'early',
#  'in',
#  'July',
#  'a',
#  'young',
#  'man',
#  'came',
#  'out',
#  'of',
#  'the',
#  'garret',
#  'in',
#  'which',
#  'he',
#  'lodged',
#  'in',
#  'S.',
#  'Place',
#  'and',
#  'walked',
#  'slowly',
#  ',',
#  'as',
#  'though',
#  'in',
#  'hesitation',
#  ',',
#  'towards',
#  'K.',
#  'bridge',
#  '.']

# %%
text.collocations()
# Out:
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Project Gutenberg-tm; Porfiry Petrovitch; Amalia Ivanovna;
# great deal; Nikodim Fomitch; young man; Ilya Petrovitch; n't know;
# Project Gutenberg; Dmitri Prokofitch; Andrey Semyonovitch; Hay Market

# %%
raw.find("PART I")
# Out:
# 5338

# %%
raw.rfind("End of Project Gutenberg's Crime")
# Out:
# 1157746

# %%
raw = raw[5338:1157743]
raw.find("PART I")
# Out:
# 0

# %% [markdown]
# ### Dealing with HTML

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode('utf8')
html[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
from bs4 import BeautifulSoup
raw = BeautifulSoup(html, "html5lib").get_text()
#aw = raw[0:4401] # remove related content
tokens = word_tokenize(raw)
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
#tokens = tokens[110:390]
text = nltk.Text(tokens)
text.concordance('gene')
# Out:
# Displaying 7 of 7 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin
# er's Polio campaign launched in Iraq Gene defect explains high blood pressure
# er's Polio campaign launched in Iraq Gene defect explains high blood pressure

# %%
text.concordance('Polio')
# Out:
# Displaying 2 of 2 matches:
# rmed Vegetables ward off Alzheimer's Polio campaign launched in Iraq Gene defec
# rmed Vegetables ward off Alzheimer's Polio campaign launched in Iraq Gene defec

# %%
text.concordance('Vegetables')
# Out:
# Displaying 2 of 2 matches:
# s' Congo Ebola outbreak confirmed Vegetables ward off Alzheimer's Polio campai
# s' Congo Ebola outbreak confirmed Vegetables ward off Alzheimer's Polio campai

# %%
text.concordance('Congo')
# Out:
# Displaying 2 of 2 matches:
# s Back pain drug 'may aid diabetics' Congo Ebola outbreak confirmed Vegetables
# s Back pain drug 'may aid diabetics' Congo Ebola outbreak confirmed Vegetables

# %%
text.concordance('Back')
# Out:
# Displaying 3 of 3 matches:
# ow : Heart risk link to big families Back pain drug 'may aid diabetics' Congo
# tion Heart risk link to big families Back pain drug 'may aid diabetics' Congo
# lic can be taught to spot strokes ^^ Back to top News Front Page | Africa | Am

# %%
text.concordance('Heart')
# Out:
# Displaying 2 of 2 matches:
# ernet sites Top Health stories now : Heart risk link to big families Back pain
#  more Health stories In This Section Heart risk link to big families Back pain

# %%
text.concordance('Health')
# Out:
# Displaying 10 of 10 matches:
#                                     Health | Blondes 'to die out in 200 years'
# RVICE A-Z INDEX SEARCH You are in : Health News Front Page Africa Americas Asi
# rtainment Science/Nature Technology Health Medical notes -- -- -- -- -- -- - T
# t is it about blondes ? 09 Apr 99 | Health Platinum blondes are labelled as du
# es are labelled as dumb 17 Apr 02 | Health Hair dye cancer alert Internet link
# tent of external internet sites Top Health stories now : Heart risk link to bi
#  ' show real symptoms Links to more Health stories are at the foot of the page
# his story to a friend Links to more Health stories In This Section Heart risk
# told to stub it out Fears over tuna health risk to babies Public can be taught
# ent | Science/Nature | Technology | Health | Talking Point | Country Profiles

# %%
text.concordance('external')
# Out:
# Displaying 1 of 1 matches:
# not responsible for the content of external internet sites Top Health stories

# %%
text.concordance('responsible')
# Out:
# Displaying 1 of 1 matches:
# rsity of Edinburgh The BBC is not responsible for the content of external inter

# %%
text.concordance('BBC')
# Out:
# Displaying 6 of 6 matches:
#                                       BBC NEWS | Health | Blondes 'to die out i
#  . They do n't disappear , '' he told BBC News Online . `` The only reason blon
# t links : University of Edinburgh The BBC is not responsible for the content of
# - -- -- -- -- -- -- -- -- -- -- -- To BBC Sport > > | To BBC Weather > > | To B
#  -- -- -- -- -- To BBC Sport > > | To BBC Weather > > | To BBC World Service >
# C Sport > > | To BBC Weather > > | To BBC World Service > > -- -- -- -- -- -- -

# %%
raw.find('The BBC')
# Out:
# 4401

# %% [markdown]
# ### Processing Search Engine Results

# %% [markdown]
# ### Processing RSS Feeds

# %%
import feedparser
llog = feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")
llog['feed']['title']
# Out:
# 'Language Log'

# %%
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[2]
post.title
# Out:
# 'German in America'

# %%
content = post.content[0].value
content[:70]
# Out:
# '<p>There\'s a <a href="https://en.wikipedia.org/wiki/Germantown,_Philad'

# %%
raw = BeautifulSoup(content, "html5lib").get_text()
word_tokenize(raw)
# Out:
# ['There',
#  "'s",
#  'a',
#  'Germantown',
#  'in',
#  'Philadelphia',
#  'and',
#  'a',
#  'German',
#  'Village',
#  'in',
#  'Columbus',
#  ',',
#  'Ohio',
#  '.',
#  'in',
#  'Fredericksburg',
#  '(',
#  'the',
#  'birthplace',
#  'of',
#  'Fleet',
#  'Admiral',
#  'Chester',
#  'Nimitz',
#  ')',
#  'and',
#  'in',
#  'New',
#  'Braunfels',
#  ',',
#  'they',
#  'speak',
#  'Texas',
#  'German',
#  ',',
#  'and',
#  'in',
#  'Amish',
#  'and',
#  'Old',
#  'Order',
#  'Mennonite',
#  'communities',
#  'in',
#  'many',
#  'states',
#  ',',
#  'they',
#  'speak',
#  'Pennsylvania',
#  'Dutch',
#  '/',
#  'German',
#  '(',
#  'Deitsch',
#  ',',
#  'Pennsylvania',
#  'Deitsch',
#  ',',
#  'Pennsilfaanisch',
#  'Deitsch',
#  ',',
#  'Hinterwäldler-Deutsch',
#  ')',
#  '.',
#  'From',
#  'a',
#  'German',
#  'friend',
#  'who',
#  'worked',
#  'for',
#  'the',
#  'American',
#  'military',
#  'government',
#  'in',
#  'Germany',
#  'after',
#  'WWII',
#  ':',
#  'While',
# ...

# %% [markdown]
# ### Reading Local Files

# %%
f = open('../Chapter 1/text.txt')
f.read()
# Out:
# 'La marcha #ConMisHijosNoTeMetas ha sido una de las más importantes respuestas conservadoras locales a las iniciativas liberales de los últimos años. La ola igualitaria gatillada a nivel mundial –reconocimiento de derechos para la comunidad homosexual, respeto y políticas de equidad para mujeres, etc.– provocó una contraola conservadora que hemos apreciado en las urnas (Brexit, Trump, victoria del No en el referéndum por la paz en Colombia).\n\nEn el Perú, la polarización en torno a valores (aún) se detenta en el campo de la sociedad civil. Periodistas y “líderes de opinión” esgrimen sus posiciones en la prensa; iglesias evangélicas y colectivos asociados a ONG en las calles. Aunque algunos atemorizan con la eminencia de un “Trump chicha” (¿Phillip Butters?), el nivel de politización en el Perú es menor en comparación con otros países (Colombia, por ejemplo).\n\nLos asuntos morales son motivaciones poderosas para el activismo ciudadano porque están directamente asociados a las identi
# ...

# %%
f = open('../Chapter 1/text.txt')
for line in f:
    print(line.strip())
# Out:
# La marcha #ConMisHijosNoTeMetas ha sido una de las más importantes respuestas conservadoras locales a las iniciativas liberales de los últimos años. La ola igualitaria gatillada a nivel mundial –reconocimiento de derechos para la comunidad homosexual, respeto y políticas de equidad para mujeres, etc.– provocó una contraola conservadora que hemos apreciado en las urnas (Brexit, Trump, victoria del No en el referéndum por la paz en Colombia).
#
# En el Perú, la polarización en torno a valores (aún) se detenta en el campo de la sociedad civil. Periodistas y “líderes de opinión” esgrimen sus posiciones en la prensa; iglesias evangélicas y colectivos asociados a ONG en las calles. Aunque algunos atemorizan con la eminencia de un “Trump chicha” (¿Phillip Butters?), el nivel de politización en el Perú es menor en comparación con otros países (Colombia, por ejemplo).
#
# ...

# %%
path = nltk.data.find('corpora/gutenberg/melville-moby_dick.txt')
raw = open(path, 'r').read()
word_tokenize(raw)
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '``',
# ...

# %% [markdown]
# ### Extracting Text from PDF, MSWord and other Binary Formats

# %% [markdown]
# - pypdf
# - pywin32

# %% [markdown]
# ### Capturing User Input

# %%
s = input("Enter some text: ")
print("You typed", len(word_tokenize(s)), "words.")
# Out:
# Enter some text: aqua yeas
# You typed 2 words.

# %% [markdown]
# ### The NLP Pipeline

# %%
raw = open('../Chapter 1/text.txt').read()
type(raw)
# Out:
# str

# %%
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
words = [w.lower() for w in tokens]
type(words)
# Out:
# list
